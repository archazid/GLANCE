# %% [markdown]
# # **Data Analysis for GLANCE**
#
# Author: Zahid Mujaddid

# %% [markdown]
# ## Tujuan
#
# Line-level defect prediction analysis results for GLANCE models

# %% [markdown]
# ## Import Libraries

# %%
# =========================
# Basic libraries
# =========================
import numpy as np  # Linear algebra
import pandas as pd  # Data processing, CSV file I/O (e.g., pd.read_csv)
import os  # Operating system interfaces

# =========================
# Visualization libraries
# =========================
import matplotlib.pyplot as plt  # Plotting library
import seaborn as sb  # Advanced data visualization
from pylab import rcParams  # Customize default figure sizes

# =========================
# Data handling
# =========================
from pandas import (
    DataFrame,
    Series,
)  # Useful for type hinting and more explicit DataFrame/Series usage

# %% [markdown]
# ## Load Summary of LLDP Results

# %%
# Load the file
sf = pd.read_csv("../exps/results/summary_overall_comparison.csv")
ssf = pd.read_csv("../exps/results/statistical_summary.csv")

# %% [markdown]
# ## Display the Result

# %%
sf
# Out:
#      Unnamed: 0 Unnamed: 1  precision    recall       far        ce       d2h  \
# 0     GLANCE-LR       Mean   0.046473  0.706785  0.182077  0.004804  0.258607
# 1     GLANCE-LR     Median   0.042185  0.783186  0.174772  0.003353  0.222830
# 2     GLANCE-LR    Std Dev   0.026576  0.190583  0.083105  0.005157  0.119331
# 3   GLANCE+File       Mean   0.046449  0.710745  0.182609  0.004783  0.256695
# 4   GLANCE+File     Median   0.044485  0.783217  0.172677  0.003387  0.217727
# 5   GLANCE+File    Std Dev   0.026117  0.191114  0.084820  0.005322  0.120057
# 6   GLANCE+Line       Mean   0.052656  0.650376  0.148165  0.005537  0.277084
# 7   GLANCE+Line     Median   0.048890  0.710794  0.145626  0.003814  0.244764
# 8   GLANCE+Line    Std Dev   0.031415  0.176836  0.065309  0.005491  0.114233
# 9      GLANCE++       Mean   0.052669  0.654541  0.148412  0.005518  0.274596
# 10     GLANCE++     Median   0.048906  0.718265  0.149366  0.003792  0.241693
# ...

# %%
sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  12 non-null     object
#  1   Unnamed: 1  12 non-null     object
#  2   precision   12 non-null     float64
#  3   recall      12 non-null     float64
#  4   far         12 non-null     float64
#  5   ce          12 non-null     float64
#  6   d2h         12 non-null     float64
#  7   mcc         12 non-null     float64
#  8   ifa         12 non-null     float64
#  9   recall_20   12 non-null     float64
#  10  ratio       12 non-null     float64
# dtypes: float64(9), object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# ## Display the Statistical Result

# %%
ssf
# Out:
#                               Comparison     Metric       p_value  \
# 0      GlancePlus-File vs BASE-Glance-LR     recall  6.135571e-01
# 1      GlancePlus-File vs BASE-Glance-LR        far  8.892762e-01
# 2      GlancePlus-File vs BASE-Glance-LR         ce  6.917762e-01
# 3      GlancePlus-File vs BASE-Glance-LR        d2h  8.809009e-01
# 4      GlancePlus-File vs BASE-Glance-LR        mcc  4.682862e-01
# 5      GlancePlus-File vs BASE-Glance-LR        ifa  2.193934e-01
# 6      GlancePlus-File vs BASE-Glance-LR  recall_20  3.647387e-01
# 7      GlancePlus-File vs BASE-Glance-LR      ratio  6.469965e-01
# 8   GlancePlus-Line-LR vs BASE-Glance-LR     recall  2.654548e-18
# 9   GlancePlus-Line-LR vs BASE-Glance-LR        far  6.403357e-22
# 10  GlancePlus-Line-LR vs BASE-Glance-LR         ce  9.187776e-15
# 11  GlancePlus-Line-LR vs BASE-Glance-LR        d2h  1.055733e-07
# 12  GlancePlus-Line-LR vs BASE-Glance-LR        mcc  3.138444e-07
# ...

# %% [markdown]
# # GLANCE-LR Evaluation

# %%
# Load the file
glancef = pd.read_csv("../Result/BASE-Glance-LR/file_result/evaluation.csv")

# %%
glancef
# Out:
#                   release  precision    recall  f1-score  accuracy      mcc  \
# ambari-2.1.0     0.290909   0.778116  0.423490  0.602849  0.265806  256/329
# ambari-2.2.0     0.446023   0.902299  0.596958  0.886631  0.585104  157/174
# ambari-2.4.0     0.585657   0.223404  0.323432  0.775465  0.256807  147/658
# ambari-2.5.0     0.437908   0.902965  0.589789  0.851261  0.562032  335/371
# ambari-2.6.0     0.513514   0.969388  0.671378  0.941380  0.681762  190/196
# ...                   ...        ...       ...       ...       ...      ...
# ww-2.3.20        0.761905   0.914286  0.831169  0.981508  0.825295    64/70
# ww-2.3.24        0.842857   0.951613  0.893939  0.990099  0.890567    59/62
# zookeeper-3.5.1  0.785714   0.440000  0.564103  0.806268  0.483426   44/100
# zookeeper-3.5.2  0.891089   0.989011  0.937500  0.966387  0.916922    90/91
# zookeeper-3.5.3  0.406593   0.973684  0.573643  0.850136  0.571161    37/38
#
# ...
